# %% [markdown]
# ## Construcción de gráficas

# %%
#Importación de librerías y funciones requeridas para la construcción de gráficas
from p1_functions import graficar_comportamiento_lineas, grafica_barras_lineas_2ejes
import pandas as pd

# %%
df_final=pd.read_csv("df_final.csv") # Lectura del dataframe final en archivo .csv

# %% [markdown]
# ### Exploración general de datos

# %%
#Llama a función para graficar comportamiento de líneas.
graficar_comportamiento_lineas(df_final, ['oro', 'plata', 'petroleo', 'gas_natural'], 'date',{"date": "Tiempo", 'value': 'Valor USD'},'Variación del precio de commodities en USD')
#Comparativa de precios de commodities

# %%
#Llama a función para graficar comportamiento de líneas.
graficar_comportamiento_lineas(df_final, ['indice_oro', 'indice_plata', 'indice_petroleo', 'indice_gas_natural'], 'date',{"date": 'Tiempo', 'value': 'Unidades'},"Variación del ínidice del precio de commodities")
#Comparativa de precios de commodities

# %%
#Llama a función para graficar comportamiento de líneas.
graficar_comportamiento_lineas(df_final,['alimentos_bebidas_es','vivienda_es','educacion_es','transporte_es','indice_general_es','alimentos_bebidas_mx','vivienda_mx','educacion_mx','transporte_mx','indice_general_mx'], 'date',{"date": 'Tiempo', 'value': 'Unidades'},"IPC vs INPC")
#Comparativa de precios de commodities

# %%
grafica_barras_lineas_2ejes(df_final,['indice_oro', 'indice_plata','indice_petroleo','indice_gas_natural'],['alimentos_bebidas_es','vivienda_es','educacion_es','transporte_es','indice_general_es'],'date','Unidades',[0,350],'Unidades',[50, 150],"Índice de precio de commodities vs IPC España")

# %%
grafica_barras_lineas_2ejes(df_final,['indice_oro', 'indice_plata','indice_petroleo','indice_gas_natural'],['alimentos_bebidas_mx','vivienda_mx','educacion_mx','transporte_mx','indice_general_mx'],'date','Unidades',[0,350],'Unidades',[50, 150],"Índice de precio de commodities vs INPC México")

# %%
grafica_barras_lineas_2ejes(df_final,['indice_oro', 'indice_plata','indice_petroleo','indice_gas_natural'],['sui_es', 'sui_mx'],'date','Unidades',[0,350],'Personas',[250, 700],"Índice de precio de commodities vs cantidad de suicidios en México y España")

# %%
grafica_barras_lineas_2ejes(df_final,['alimentos_bebidas_es','vivienda_es','educacion_es','transporte_es','indice_general_es','alimentos_bebidas_mx','vivienda_mx','educacion_mx','transporte_mx','indice_general_mx'],['sui_es', 'sui_mx'],'date','Unidades',[0,175],'Personas',[250, 700],"IPC / INPC vs cantidad de suicidios en México / España")
